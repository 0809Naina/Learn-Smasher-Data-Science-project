# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("F:/LEARNER SMASHER/netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 1.To get the number of rows and columns

# %%
df.shape
# Out:
# (8807, 12)

# %%
print("Number of rows", df.shape[0])
print("Number of columns", df.shape[1])
# Out:
# Number of rows 8807
# Number of columns 12

# %% [markdown]
# 2.To get the information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# 3.To get the overall statistics

# %%
df.describe()#column wise
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.describe(include="all")#row wise
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %% [markdown]
# 4.To get the null values

# %%
df.isnull().any()
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration         True
# listed_in       False
# description     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().any(axis=1)# for columns
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
len(df[df.isnull().any(axis=1)])# for columns
# Out:
# 3475

# %%
df.isnull().any(axis=0)# for rows
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration         True
# listed_in       False
# description     False
# dtype: bool

# %% [markdown]
# 5.To check the duplicated values

# %%
dup=df.duplicated()
dup
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
print("If any duplicated values are",dup)
# Out:
# If any duplicated values are 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %% [markdown]
# 6.For "Ganglands" what is the show id and who is the director of this show?

# %%
df[df['title'].isin(['Ganglands'])]
# Out:
#   show_id     type      title         director  \
# 2      s3  TV Show  Ganglands  Julien Leclercq
#
#                                                 cast country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
#
#            date_added  release_year rating  duration  \
# 2  September 24, 2021          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 2  To protect his family from a powerful drug lor...

# %% [markdown]
# 7.In which year highest number of TV shows and Movies were released? Show with the bar graph .

# %%
df['Date']=pd.to_datetime(df['date_added'])
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
a=df['Date']=pd.to_datetime(df['date_added']).value_counts()
a
# Out:
# 2020-01-01    110
# 2019-11-01     91
# 2018-03-01     75
# 2019-12-31     74
# 2018-10-01     71
#              ...
# 2017-02-21      1
# 2017-02-07      1
# 2017-01-29      1
# 2017-01-25      1
# 2020-01-11      1
# Name: date_added, Length: 1714, dtype: int64

# %%
sns.barplot(x='date_added', y='release_year', data=df)
# Out:
# <AxesSubplot:xlabel='date_added', ylabel='release_year'>

# %% [markdown]
# 8.How many movies and shows are in the dataset ? Show in the graph

# %%
df['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(df['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# 9.Show all the movies in the year in 2016

# %%
df[(df['type']=='Movie') & (df['release_year']==2016)].head(3)
# Out:
#     show_id   type                          title         director  \
# 152    s153  Movie  Janoskians: Untold and Untrue     Brett Weiner
# 203    s204  Movie           Kyaa Kool Hain Hum 3     Umesh Ghadge
# 281    s282  Movie                  Brother Jekwu  Charles Uwagbai
#
#                                                   cast        country  \
# 152  Jai Brooks, Luke Brooks, James Yammouni, Danie...  United States
# 203  Tusshar Kapoor, Aftab Shivdasani, Krishna Abhi...          India
# 281  Mike Ezuruonye, Juliet Ochienge, Angela Okorie...        Nigeria
#
#             date_added  release_year rating duration  \
# 152  September 1, 2021          2016  TV-MA   88 min
# 203    August 27, 2021          2016  TV-MA  124 min
# 281    August 11, 2021          2016  TV-14  101 min
#
#                           listed_in  \
# 152                        Comedies
# 203  Comedies, International Movies
# 281  Comedies, International Movies
#
# ...

# %% [markdown]
# 10.Show all the TV shows released in India

# %%
df[(df['type']=='TV Show') & (df['country']=='India')]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# 11.Show top of 5 directors who have gave highest number of TV Shows and Movies to netflix

# %%
df['director'].value_counts()
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %% [markdown]
# 12.Show all the records where 'type is Movie and listed_in is comedies' or 'country is India'

# %%
df[(df['type']=='Movie') & (df['listed_in']=='Comedies') |(df['country']=='India')]
# Out:
#      show_id     type                title                 director  \
# 4         s5  TV Show         Kota Factory                      NaN
# 24       s25    Movie                Jeans               S. Shankar
# 27       s28    Movie            Grown Ups             Dennis Dugan
# 39       s40  TV Show         Chhota Bheem                      NaN
# 50       s51  TV Show        Dharmakshetra                      NaN
# ...      ...      ...                  ...                      ...
# 8773   s8774    Movie  Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show      Yeh Meri Family                      NaN
# 8798   s8799    Movie             Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                Zenda           Avadhoot Gupte
# 8806   s8807    Movie               Zubaan              Mozez Singh
#
#                                                    cast        country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...

# %%
new_df=df.dropna()
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 13.In how much TVshows/ Movies is Vicky Kaushal was casted ?

# %%
new_df[new_df['cast'].str.contains('Vicky Kaushal')]
# Out:
#      show_id   type                 title  \
# 1678   s1679  Movie      Raman Raghav 2.0
# 4507   s4508  Movie                 Sanju
# 4825   s4826  Movie          Lust Stories
# 5040   s5041  Movie  Love Per Square Foot
# 8806   s8807  Movie                Zubaan
#
#                                                director  \
# 1678                                     Anurag Kashyap
# 4507                                    Rajkumar Hirani
# 4825  Zoya Akhtar, Karan Johar, Anurag Kashyap, Diba...
# 5040                                       Anand Tiwari
# 8806                                        Mozez Singh
#
#                                                    cast country  \
# 1678  Nawazuddin Siddiqui, Vicky Kaushal, Sobhita Dh...   India
# 4507  Ranbir Kapoor, Vicky Kaushal, Paresh Rawal, So...   India
# 4825  Vicky Kaushal, Bhumi Pednekar, Radhika Apte, N...   India
# 5040  Vicky Kaushal, Angira Dhar, Alankrita Sahai, R...   India
# ...

# %% [markdown]
# 14.What are the different ratings defined by netflix , and how many Movies got TV-14 Rating in India ?

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
new_df[(new_df['rating'])=='TV-14']
# Out:
#      show_id     type                                              title  \
# 8         s9  TV Show                      The Great British Baking Show
# 24       s25    Movie                                              Jeans
# 51       s52    Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53    Movie  InuYasha the Movie 3: Swords of an Honorable R...
# 56       s57    Movie           Naruto Shippuden the Movie: Blood Prison
# ...      ...      ...                                                ...
# 8772   s8773    Movie                              Yamla Pagla Deewana 2
# 8774   s8775    Movie                                          يوم الدين
# 8794   s8795    Movie                                             اشتباك
# 8799   s8800    Movie                                              Zenda
# 8806   s8807    Movie                                             Zubaan
#
#                director                                               cast  \
# ...

# %% [markdown]
# 15.Which country having the highest number of TV Shows ? Show with the graph

# %%
country_the_highest_number_of_TV_Shows= new_df[new_df['type'] == 'TV Show']
country_the_highest_number_of_TV_Shows.head()
# Out:
#     show_id     type                                 title  \
# 8        s9  TV Show         The Great British Baking Show
# 198    s199  TV Show  King of Boys: The Return of the King
# 273    s274  TV Show                         Gone for Good
# 276    s277  TV Show                               Valeria
# 297    s298  TV Show                              Navarasa
#
#                                               director  \
# 8                                      Andy Devonshire
# 198                                       Kemi Adetiba
# 273                                 Juan Carlos Medina
# 276                                      Inma Torrente
# 297  Bejoy Nambiar, Priyadarshan, Karthik Narain, V...
#
#                                                   cast         country  \
# 8    Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...  United Kingdom
# 198  Sola Sobowale, Toni Tones, Richard Mofe-Damijo...         Nigeria
# ...

# %%
country_the_highest_number_of_TV_Shows.country.value_counts().head()
# Out:
# United States     27
# United Kingdom    19
# Japan             10
# South Korea       10
# Spain              7
# Name: country, dtype: int64

# %%
country_the_highest_number_of_TV_Shows.country.value_counts().head().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='country'>
